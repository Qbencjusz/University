# %%
# !pip install git+https://github.com/baopng/NSGA-II.git
# Out:
# Collecting git+https://github.com/baopng/NSGA-II.git
#   Cloning https://github.com/baopng/NSGA-II.git to c:\users\gracz\appdata\local\temp\pip-req-build-3rp5hp5q
# Building wheels for collected packages: nsga-2
#   Building wheel for nsga-2 (setup.py): started
#   Building wheel for nsga-2 (setup.py): finished with status 'done'
#   Created wheel for nsga-2: filename=nsga_2-0.1-py3-none-any.whl size=4679 sha256=04d6f21865bf9278457b95fdf3c735fa858f491f40a7d81c4e8a3ab17ecfa9c8
#   Stored in directory: C:\Users\Gracz\AppData\Local\Temp\pip-ephem-wheel-cache-x_0xp7lr\wheels\5e\7b\97\5ca6bc74137f18ef5b22b0dfce885459b146d579413b7d05fd
# Successfully built nsga-2
# Installing collected packages: nsga-2
# Successfully installed nsga-2-0.1

# %%
from nsga2.problem import Problem
from nsga2.evolution import Evolution
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# ### SCH

# %%
def f1(x):
    return x**2

def f2(x):
    return (x-2)**2

problem = Problem(num_of_variables=1, objectives=[f1, f2], variables_range=[(-10**3, 10**3)])
evo = Evolution(problem)
evol = evo.evolve()
func = [i.objectives for i in evol]

function1 = [i[0] for i in func]
function2 = [i[1] for i in func]
plt.xlabel('Function 1', fontsize=15)
plt.ylabel('Function 2', fontsize=15)
plt.scatter(function1, function2)
plt.show()

# %% [markdown]
# ### KUR

# %%
def f1(x):
    s = 0
    for i in range(len(x)-1):
        s += -10*math.exp(-0.2*math.sqrt(x[i]**2 + x[i+1]**2))
    return s

def f2(x):
    s = 0
    for i in range(len(x)):
        s += abs(x[i])**0.8 + 5*math.sin(x[i]**3)
    return s

problem = Problem(num_of_variables=3, objectives=[f1, f2], variables_range=[(-5, 5)], same_range=True, expand=False)
evo = Evolution(problem, mutation_param=20)
func = [i.objectives for i in evo.evolve()]

function1 = [i[0] for i in func]
function2 = [i[1] for i in func]
plt.xlabel('Function 1', fontsize=15)
plt.ylabel('Function 2', fontsize=15)
plt.scatter(function1, function2)
plt.show()

# %% [markdown]
# ### ZDT1

# %%
def f1(x):
    return x[0]

def f2(x):
    s = 0
    for i in range(1, len(x)):
        s += x[i]
    g = 1 + 9 * s / (len(x)-1)
    h = 1 - np.sqrt(f1(x) / g)
    return g * h

problem = Problem(num_of_variables=30, objectives=[f1, f2], variables_range=[(0, 1)], same_range=True, expand=False)
evo = Evolution(problem, mutation_param=30)
func = [i.objectives for i in evo.evolve()]

function1 = [i[0] for i in func]
function2 = [i[1] for i in func]
plt.xlabel('Function 1', fontsize=15)
plt.ylabel('Function 2', fontsize=15)
plt.scatter(function1, function2)
plt.show()
